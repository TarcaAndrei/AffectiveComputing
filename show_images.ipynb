# %%
from dataset_emotic import DatasetEmotic
from plots import plot_image_with_bboxes

dataset = DatasetEmotic(dataset_type="train")
dataset_val = DatasetEmotic(dataset_type="val")
dataset_test = DatasetEmotic(dataset_type="test")

# %%
img, lbl = dataset[10698]
plot_image_with_bboxes(img, lbl)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 img, lbl = dataset[10698]
# ----> 2 plot_image_with_bboxes(img, lbl)
#
# File ~/plots.py:40, in plot_image_with_bboxes(image, bboxes)
#      38 fig, ax = plt.subplots(figsize=(10, 10))
#      39 labels = bbox_info["labels"]
# ---> 40 ax.imshow(cropped_img, cmap='gray' if len(cropped_img.shape) == 2 else None)
#      41 label_text = ", ".join(map(str, labels))  # Assuming labels is a list of integers/strings
#      42 ax.text(x_min, y_min - 5, label_text, color='red', fontsize=10, backgroundcolor="white")
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# ...
